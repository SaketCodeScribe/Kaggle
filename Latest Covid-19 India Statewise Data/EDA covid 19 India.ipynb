# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from scipy.stats import boxcox, norm
import plotly.express as px

warnings.filterwarnings('ignore')

# %% [markdown]
# # Load dataset

# %%
data = pd.read_csv('../input/latest-covid19-india-statewise-data/Latest Covid-19 India Status.csv')

# %%
data.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman and Nicobar         7584       8        7447     129
# 1       Andhra Pradesh      2030849   14652     2002187   14010
# 2    Arunachal Pradesh        53807     533       53004     270
# 3                Assam       595669    5615      584296    5758
# 4                Bihar       725833      77      716098    9658
#
#    Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 0              0.11                98.19             1.70
# 1              0.72                98.59             0.69
# 2              0.99                98.51             0.50
# 3              0.94                98.09             0.97
# 4              0.01                98.66             1.33

# %%
print(f"Shape of dataset: {data.shape}")
# Out:
# Shape of dataset: (36, 8)

# %%
print(f"Column of dataset: {data.columns}")
# Out:
# Column of dataset: Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio (%)', 'Discharge Ratio (%)', 'Death Ratio (%)'],
#       dtype='object')

# %%
print("Info. of dataset\n\n")
print(data.info())
# Out:
# Info. of dataset
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State/UTs            36 non-null     object
#  1   Total Cases          36 non-null     int64
#  2   Active               36 non-null     int64
#  3   Discharged           36 non-null     int64
#  4   Deaths               36 non-null     int64
#  5   Active Ratio (%)     36 non-null     float64
#  6   Discharge Ratio (%)  36 non-null     float64
#  7   Death Ratio (%)      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB
# None

# %%
print("Central tendency of dataset\n\n")
data.describe().T
# Out:
# Central tendency of dataset
#                      count           mean           std      min         25%  \
# Total Cases           36.0  924710.527778  1.363114e+06  7584.00  76990.0000
# Active                36.0   10061.305556  3.551245e+04     5.00    153.5000
# Discharged            36.0  902337.750000  1.319414e+06  7447.00  72433.5000
# Deaths                36.0   12311.472222  2.370810e+04     4.00    814.0000
# Active Ratio (%)      36.0       1.175000  3.103863e+00     0.01      0.0500
# Discharge Ratio (%)   36.0      97.558611  2.983397e+00    81.33     97.7225
# Death Ratio (%)       36.0       1.266667  5.663215e-01     0.04      0.9550
#
#                            50%           75%         max
# Total Cases          471874.00  1.007885e+06  6500617.00
# Active                  556.50  5.343500e+03   209335.00
# Discharged           463562.50  9.939285e+05  6309021.00
# Deaths                 5445.50  1.367100e+04   138169.00
# Active Ratio (%)          0.46  7.975000e-01       18.34
# Discharge Ratio (%)      98.28  9.865250e+01       99.92
# Death Ratio (%)           1.30  1.585000e+00        2.74

# %%
fig, axes = plt.subplots(figsize=(15,5))
plt.hist(data['Total Cases'],bins=20)
plt.xlabel('Total Cases')

plt.title("Frequency plot of Total Cases")
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
sns.distplot(data['Total Cases'],kde=True,fit=norm,ax=axes,bins=20)
plt.title('Distplot of Total Cases')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
plt.hist(data['Active'],bins=100)
plt.xlabel('Active')
plt.title('Frequency plot of Active cases')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
sns.distplot(data['Active'],kde=True,fit=norm,ax=axes,bins=100)
plt.title('Distplot of Active Cases')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
plt.hist(data['Discharged'],bins=20)
plt.xlabel('Discharged')

plt.title("Frequency plot of Discharged Cases")
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
sns.distplot(data['Discharged'],kde=True,fit=norm,ax=axes,bins=20)
plt.title('Distplot of Discharged Cases')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
plt.hist(data['Deaths'],bins=20)
plt.xlabel('Deaths')

plt.title("Frequency plot of Death Cases")
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
sns.distplot(data['Deaths'],kde=True,fit=norm,ax=axes,bins=20)
plt.title('Distplot of Death Cases')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
plt.hist(data['Active Ratio (%)'],bins=20)
plt.xlabel('Active Ratio (%)')

plt.title("Frequency plot of Active Ratio (%)")
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
sns.distplot(data['Active Ratio (%)'],kde=True,fit=norm,ax=axes,bins=20)
plt.title('Distplot of Active Ratio (%)')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
plt.hist(data['Discharge Ratio (%)'],bins=20)
plt.xlabel('Discharge Ratio (%)')

plt.title("Frequency plot of Discharge Ratio (%)")
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
sns.distplot(data['Discharge Ratio (%)'],kde=True,fit=norm,ax=axes,bins=20)
plt.title('Distplot of Discharge Ratio (%)')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
plt.hist(data['Death Ratio (%)'],bins=20)
plt.xlabel('Death Ratio (%)')

plt.title("Frequency plot of Death Ratio (%)")
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,5))
sns.distplot(data['Death Ratio (%)'],kde=True,fit=norm,ax=axes,bins=20)
plt.title('Distplot of Death Ratio (%)')
plt.show()

# %% [markdown]
# **Insights**
# * Majority of the states has less than 1e6 total cases.
# * Majority of the states has less than 5e4 active cases.
# * Majority of the states has less than 1e6 discharged cases.
# * Majority of the states has less than 2e4 active cases.

# %%
print(f"Total cases over India: {data['Total Cases'].sum()} cases")
print(f"Total active cases over India: {data['Active'].sum()} cases")
print(f"Total discharged cases over India: {data['Discharged'].sum()} cases")
print(f"Total death cases over India: {data['Deaths'].sum()} cases\n\n")

print(f"Most cases over India: {data['Total Cases'].max()} cases, State: {data[data['Total Cases']==data['Total Cases'].max()]['State/UTs'].values[0]}")
print(f"Least cases over India: {data['Total Cases'].min()} cases, State: {data[data['Total Cases']==data['Total Cases'].min()]['State/UTs'].values[0]}\n\n")

print(f"Most active cases over India: {data['Active'].max()} cases, State: {data[data['Active']==data['Active'].max()]['State/UTs'].values[0]}")
print(f"Least active cases over India: {data['Active'].min()} cases, State: {data[data['Active']==data['Active'].min()]['State/UTs'].values[0]}\n\n")

print(f"Most discharged cases over India: {data['Discharged'].max()} cases, State: {data[data['Discharged']==data['Discharged'].max()]['State/UTs'].values[0]}")
print(f"Least discharged cases over India: {data['Discharged'].min()} cases, State: {data[data['Discharged']==data['Discharged'].min()]['State/UTs'].values[0]}\n\n")

print(f"Most deaths cases over India: {data['Deaths'].max()} cases, State: {data[data['Deaths']==data['Deaths'].max()]['State/UTs'].values[0]}")
print(f"Least deaths cases over India: {data['Deaths'].min()} cases, State: {data[data['Deaths']==data['Deaths'].min()]['State/UTs'].values[0]}\n\n")

print(f"Most active ratio (%) cases over India: {data['Active Ratio (%)'].max()} %, State: {data[data['Active Ratio (%)']==data['Active Ratio (%)'].max()]['State/UTs'].values[0]}")
print(f"Least active ratio (%) cases over India: {data['Active Ratio (%)'].min()} %, State: {data[data['Active Ratio (%)']==data['Active Ratio (%)'].min()]['State/UTs'].values[0]}\n\n")

print(f"Most discharge ratio (%) cases over India: {data['Discharge Ratio (%)'].max()} %, State: {data[data['Discharge Ratio (%)']==data['Discharge Ratio (%)'].max()]['State/UTs'].values[0]}")
print(f"Least discharge ratio (%) cases over India: {data['Discharge Ratio (%)'].min()} %, State: {data[data['Discharge Ratio (%)']==data['Discharge Ratio (%)'].min()]['State/UTs'].values[0]}\n\n")

print(f"Most death ratio (%) cases over India: {data['Death Ratio (%)'].max()} %, State: {data[data['Death Ratio (%)']==data['Death Ratio (%)'].max()]['State/UTs'].values[0]}")
print(f"Least death ratio (%) cases over India: {data['Death Ratio (%)'].min()} %, State: {data[data['Death Ratio (%)']==data['Death Ratio (%)'].min()]['State/UTs'].values[0]}\n\n")
# Out:
# Total cases over India: 33289579 cases
# Total active cases over India: 362207 cases
# Total discharged cases over India: 32484159 cases
# Total death cases over India: 443213 cases
#
#
# Most cases over India: 6500617 cases, State: Maharashtra
# Least cases over India: 7584 cases, State: Andaman and Nicobar
#
#
# Most active cases over India: 209335 cases, State: Kerala
# Least active cases over India: 5 cases, State: Dadra and Nagar Haveli and Daman and Diu
#
#
# Most discharged cases over India: 6309021 cases, State: Maharashtra
# Least discharged cases over India: 7447 cases, State: Andaman and Nicobar
#
#
# Most deaths cases over India: 138169 cases, State: Maharashtra
# Least deaths cases over India: 4 cases, State: Dadra and Nagar Haveli and Daman and Diu
#
#
# Most active ratio (%) cases over India: 18.34 %, State: Mizoram
# Least active ratio (%) cases over India: 0.01 %, State: Bihar
#
#
# Most discharge ratio (%) cases over India: 99.92 %, State: Dadra and Nagar Haveli and Daman and Diu
# Least discharge ratio (%) cases over India: 81.33 %, State: Mizoram
#
#
# Most death ratio (%) cases over India: 2.74 %, State: Punjab
# Least death ratio (%) cases over India: 0.04 %, State: Dadra and Nagar Haveli and Daman and Diu

# %%
fig, axes = plt.subplots(figsize=(15,5))
corr = data.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
plot = sns.heatmap(data.corr(), annot=True, mask=mask)
fig.suptitle('Correlation heat map')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,10))
plot = sns.barplot(y='State/UTs',x='Total Cases',data=data, ax=axes)
fig.suptitle('Bar plot of Total Cases v/s State/UTs')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,10))
plot = sns.barplot(y='State/UTs',x='Active',data=data, ax=axes)
fig.suptitle('Bar plot of Active Cases v/s State/UTs')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,10))
plot = sns.barplot(y='State/UTs',x='Discharged',data=data, ax=axes)
fig.suptitle('Bar plot of Discharged Cases v/s State/UTs')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,10))
plot = sns.barplot(y='State/UTs',x='Deaths',data=data, ax=axes)
fig.suptitle('Bar plot of Deaths v/s State/UTs')
plt.show()

# %%
px.bar(data, x="State/UTs", y="Total Cases", color="Death Ratio (%)", title="Total Cases per State : ")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="fa519d6f-6942-4b07-95c7-2a8c294373db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa519d6f-6942-4b07-95c7-2a8c294373db")) {                    Plotly.newPlot(                        "fa519d6f-6942-4b07-95c7-2a8c294373db",                        [{"alignmentgroup":"True","hovertemplate":"State/UTs=%{x}<br>Total Cases=%{y}<br>Death Ratio (%)=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[1.7,0.69,0.5,0.97,1.33,1.25,1.35,0.04,1.74,1.84,1.22,1.27,1.69,1.35,1.47,1.27,0.52,1.0,0.49,1.33,2.13,1.55,1.73,0.33,2.1,0.8,1.46,2.74,0.94,1.23,1.34,0.59,0.96,1.34,2.15,1.19],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"xaxis":"x","y":[7584,2030849,53807,595669,725833,65160,1004902,10670,1438250,174891,825629,770659,215893,326990,348079,2962408,4390489,20608,10353,792353,6500617,117230,78359,72883,30657,1016833,124836,601072,954198,30650,2635419,661866,83672,1709555,343242,1557414],"yaxis":"y"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"Death Ratio (%)"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666 ...

# %%
px.bar(data, x="State/UTs", y="Total Cases", color="Active Ratio (%)", title="Total Cases per State : ")
# Out:
# <div>                            <div id="ff718340-674d-4b7b-a08d-d983d7daa086" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff718340-674d-4b7b-a08d-d983d7daa086")) {                    Plotly.newPlot(                        "ff718340-674d-4b7b-a08d-d983d7daa086",                        [{"alignmentgroup":"True","hovertemplate":"State/UTs=%{x}<br>Total Cases=%{y}<br>Active Ratio (%)=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.11,0.72,0.99,0.94,0.01,0.05,0.04,0.05,0.03,0.4,0.02,0.05,0.7,0.38,0.03,0.55,4.77,0.15,0.05,0.02,0.82,2.23,2.37,18.34,1.89,0.58,0.69,0.05,0.01,2.64,0.63,0.79,0.58,0.01,0.09,0.52],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"xaxis":"x","y":[7584,2030849,53807,595669,725833,65160,1004902,10670,1438250,174891,825629,770659,215893,326990,348079,2962408,4390489,20608,10353,792353,6500617,117230,78359,72883,30657,1016833,124836,601072,954198,30650,2635419,661866,83672,1709555,343242,1557414],"yaxis":"y"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"Active Ratio (%)"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66 ...

# %%
px.bar(data, x="State/UTs", y="Total Cases", color="Discharge Ratio (%)", title="Total Cases per State : ")
# Out:
# <div>                            <div id="c9460b05-2780-446a-86bb-97126de75490" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9460b05-2780-446a-86bb-97126de75490")) {                    Plotly.newPlot(                        "c9460b05-2780-446a-86bb-97126de75490",                        [{"alignmentgroup":"True","hovertemplate":"State/UTs=%{x}<br>Total Cases=%{y}<br>Discharge Ratio (%)=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[98.19,98.59,98.51,98.09,98.66,98.7,98.61,99.92,98.23,97.76,98.76,98.68,97.61,98.27,98.49,98.18,94.72,98.85,99.46,98.66,97.05,96.22,95.89,81.33,96.0,98.62,97.85,97.21,99.05,96.13,98.04,98.62,98.46,98.65,97.76,98.29],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"xaxis":"x","y":[7584,2030849,53807,595669,725833,65160,1004902,10670,1438250,174891,825629,770659,215893,326990,348079,2962408,4390489,20608,10353,792353,6500617,117230,78359,72883,30657,1016833,124836,601072,954198,30650,2635419,661866,83672,1709555,343242,1557414],"yaxis":"y"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"Discharge Ratio (%)"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd37 ...

# %% [markdown]
# **2D Histogram**

# %%
px.density_heatmap(data, x="Deaths", y="Total Cases",nbinsx=20, nbinsy=20)
# Out:
# <div>                            <div id="46887019-b7ff-480a-a9eb-1fbc20ce7585" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46887019-b7ff-480a-a9eb-1fbc20ce7585")) {                    Plotly.newPlot(                        "46887019-b7ff-480a-a9eb-1fbc20ce7585",                        [{"coloraxis":"coloraxis","hovertemplate":"Deaths=%{x}<br>Total Cases=%{y}<br>count=%{z}<extra></extra>","name":"","nbinsx":20,"nbinsy":20,"type":"histogram2d","x":[129,14010,270,5758,9658,817,13558,4,25083,3217,10082,9807,3639,4414,5133,37517,22650,207,51,10517,138169,1812,1359,241,645,8104,1823,16457,8954,377,35190,3897,805,22883,7389,18587],"xaxis":"x","xbingroup":"x","y":[7584,2030849,53807,595669,725833,65160,1004902,10670,1438250,174891,825629,770659,215893,326990,348079,2962408,4390489,20608,10353,792353,6500617,117230,78359,72883,30657,1016833,124836,601072,954198,30650,2635419,661866,83672,1709555,343242,1557414],"yaxis":"y","ybingroup":"y"}],                        {"coloraxis":{"colorbar":{"title":{"text":"count"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram ...

# %%
px.density_heatmap(data, x="Active", y="Total Cases",nbinsx=20, nbinsy=20)
# Out:
# <div>                            <div id="bd6b6f0e-9f68-42c7-8a51-97c5e822f061" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd6b6f0e-9f68-42c7-8a51-97c5e822f061")) {                    Plotly.newPlot(                        "bd6b6f0e-9f68-42c7-8a51-97c5e822f061",                        [{"coloraxis":"coloraxis","hovertemplate":"Active=%{x}<br>Total Cases=%{y}<br>count=%{z}<extra></extra>","name":"","nbinsx":20,"nbinsy":20,"type":"histogram2d","x":[8,14652,533,5615,77,32,376,5,377,702,161,351,1521,1247,117,16269,209335,30,5,131,53427,2617,1859,13369,580,5919,860,309,90,809,16522,5253,485,175,293,8096],"xaxis":"x","xbingroup":"x","y":[7584,2030849,53807,595669,725833,65160,1004902,10670,1438250,174891,825629,770659,215893,326990,348079,2962408,4390489,20608,10353,792353,6500617,117230,78359,72883,30657,1016833,124836,601072,954198,30650,2635419,661866,83672,1709555,343242,1557414],"yaxis":"y","ybingroup":"y"}],                        {"coloraxis":{"colorbar":{"title":{"text":"count"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{ ...

# %%
px.density_heatmap(data, x="Discharged", y="Total Cases",nbinsx=20, nbinsy=20)
# Out:
# <div>                            <div id="d6e87f7f-59e6-41e7-bbc9-7e9eef21ddef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6e87f7f-59e6-41e7-bbc9-7e9eef21ddef")) {                    Plotly.newPlot(                        "d6e87f7f-59e6-41e7-bbc9-7e9eef21ddef",                        [{"coloraxis":"coloraxis","hovertemplate":"Discharged=%{x}<br>Total Cases=%{y}<br>count=%{z}<extra></extra>","name":"","nbinsx":20,"nbinsy":20,"type":"histogram2d","x":[7447,2002187,53004,584296,716098,64311,990968,10661,1412790,170972,815386,760501,210733,321329,342829,2908622,4158504,20371,10297,781705,6309021,112801,75141,59273,29432,1002810,122153,584306,945154,29464,2583707,652716,82382,1686497,335560,1530731],"xaxis":"x","xbingroup":"x","y":[7584,2030849,53807,595669,725833,65160,1004902,10670,1438250,174891,825629,770659,215893,326990,348079,2962408,4390489,20608,10353,792353,6500617,117230,78359,72883,30657,1016833,124836,601072,954198,30650,2635419,661866,83672,1709555,343242,1557414],"yaxis":"y","ybingroup":"y"}],                        {"coloraxis":{"colorbar":{"title":{"text":"count"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888 ...

# %%
px.scatter(data, x="Active", y="Total Cases", color=data['State/UTs'], title="Total cases v/s Active")
# Out:
# <div>                            <div id="4687f5d2-05db-406b-9546-2061b7bf3e83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4687f5d2-05db-406b-9546-2061b7bf3e83")) {                    Plotly.newPlot(                        "4687f5d2-05db-406b-9546-2061b7bf3e83",                        [{"hovertemplate":"State/UTs=Andaman and Nicobar<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andaman and Nicobar","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andaman and Nicobar","orientation":"v","showlegend":true,"type":"scatter","x":[8],"xaxis":"x","y":[7584],"yaxis":"y"},{"hovertemplate":"State/UTs=Andhra Pradesh<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[14652],"xaxis":"x","y":[2030849],"yaxis":"y"},{"hovertemplate":"State/UTs=Arunachal Pradesh<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Arunachal Pradesh","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Arunachal Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[533],"xaxis":"x","y":[53807],"yaxis":"y"},{"hovertemplate":"State/UTs=Assam<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"type":"scatter","x":[5615],"xaxis":"x","y":[595669],"yaxis":"y"},{"hovertemplate":"State/UTs=Bihar<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"type":"scatter","x":[77],"xaxis":"x","y":[725833],"yaxis":"y"},{"hovertemplate":"State/UTs=Chandigarh<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chandigarh","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Chandigarh","orientation":"v","showlegend":true,"type":"scatter","x":[32],"xaxis":"x","y":[65160],"yaxis":"y"},{"hovertemplate":"State/UTs=Chhattisgarh<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"type":"scatter","x":[376],"xaxis":"x","y":[1004902],"yaxis":"y"},{"hovertemplate":"State/UTs=Dadra and Nagar Haveli and Daman and Diu<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Dadra and Nagar Haveli and Daman and Diu","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Dadra and Nagar Haveli and Daman and Diu","orientation":"v","showlegend":true,"type":"scatter","x":[5],"xaxis":"x","y":[10670],"yaxis":"y"},{"hovertemplate":"State/UTs=Delhi<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"type":"scatter","x":[377],"xaxis":"x","y":[1438250],"yaxis":"y"},{"hovertemplate":"State/UTs=Goa<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"type":"scatter","x":[702],"xaxis":"x","y":[174891],"yaxis":"y"},{"hovertemplate":"State/UTs=Gujarat<br>Active=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Gujarat","orientation":"v","showlegend":true,"type":"scatter","x":[161],"xaxis":"x","y":[825629],"yaxis":"y"},{"hovertemplate":"State/UTs=Haryana<br>Active=%{x}<br>Total Cases=%{y}< ...

# %%
px.scatter(data, x="Deaths", y="Total Cases", color=data['State/UTs'], title="Total cases v/s Deaths")
# Out:
# <div>                            <div id="871e2b2a-c1c6-4ab8-af90-fa5d4f5a7919" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("871e2b2a-c1c6-4ab8-af90-fa5d4f5a7919")) {                    Plotly.newPlot(                        "871e2b2a-c1c6-4ab8-af90-fa5d4f5a7919",                        [{"hovertemplate":"State/UTs=Andaman and Nicobar<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andaman and Nicobar","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andaman and Nicobar","orientation":"v","showlegend":true,"type":"scatter","x":[129],"xaxis":"x","y":[7584],"yaxis":"y"},{"hovertemplate":"State/UTs=Andhra Pradesh<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[14010],"xaxis":"x","y":[2030849],"yaxis":"y"},{"hovertemplate":"State/UTs=Arunachal Pradesh<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Arunachal Pradesh","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Arunachal Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[270],"xaxis":"x","y":[53807],"yaxis":"y"},{"hovertemplate":"State/UTs=Assam<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"type":"scatter","x":[5758],"xaxis":"x","y":[595669],"yaxis":"y"},{"hovertemplate":"State/UTs=Bihar<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"type":"scatter","x":[9658],"xaxis":"x","y":[725833],"yaxis":"y"},{"hovertemplate":"State/UTs=Chandigarh<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chandigarh","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Chandigarh","orientation":"v","showlegend":true,"type":"scatter","x":[817],"xaxis":"x","y":[65160],"yaxis":"y"},{"hovertemplate":"State/UTs=Chhattisgarh<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"type":"scatter","x":[13558],"xaxis":"x","y":[1004902],"yaxis":"y"},{"hovertemplate":"State/UTs=Dadra and Nagar Haveli and Daman and Diu<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Dadra and Nagar Haveli and Daman and Diu","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Dadra and Nagar Haveli and Daman and Diu","orientation":"v","showlegend":true,"type":"scatter","x":[4],"xaxis":"x","y":[10670],"yaxis":"y"},{"hovertemplate":"State/UTs=Delhi<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"type":"scatter","x":[25083],"xaxis":"x","y":[1438250],"yaxis":"y"},{"hovertemplate":"State/UTs=Goa<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"type":"scatter","x":[3217],"xaxis":"x","y":[174891],"yaxis":"y"},{"hovertemplate":"State/UTs=Gujarat<br>Deaths=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Gujarat","orientation":"v","showlegend":true,"type":"scatter","x":[10082],"xaxis":"x","y":[825629],"yaxis":"y"},{"hovertemplate":"State/UTs=Haryana<br>Deaths=%{x}<br>Total ...

# %%
px.scatter(data, x="Discharged", y="Total Cases", color=data['State/UTs'], title="Total cases v/s Discharged")
# Out:
# <div>                            <div id="3a08984d-ead3-49d8-85a1-8b28164b3d1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a08984d-ead3-49d8-85a1-8b28164b3d1c")) {                    Plotly.newPlot(                        "3a08984d-ead3-49d8-85a1-8b28164b3d1c",                        [{"hovertemplate":"State/UTs=Andaman and Nicobar<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andaman and Nicobar","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andaman and Nicobar","orientation":"v","showlegend":true,"type":"scatter","x":[7447],"xaxis":"x","y":[7584],"yaxis":"y"},{"hovertemplate":"State/UTs=Andhra Pradesh<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[2002187],"xaxis":"x","y":[2030849],"yaxis":"y"},{"hovertemplate":"State/UTs=Arunachal Pradesh<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Arunachal Pradesh","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Arunachal Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[53004],"xaxis":"x","y":[53807],"yaxis":"y"},{"hovertemplate":"State/UTs=Assam<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"type":"scatter","x":[584296],"xaxis":"x","y":[595669],"yaxis":"y"},{"hovertemplate":"State/UTs=Bihar<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"type":"scatter","x":[716098],"xaxis":"x","y":[725833],"yaxis":"y"},{"hovertemplate":"State/UTs=Chandigarh<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chandigarh","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Chandigarh","orientation":"v","showlegend":true,"type":"scatter","x":[64311],"xaxis":"x","y":[65160],"yaxis":"y"},{"hovertemplate":"State/UTs=Chhattisgarh<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"type":"scatter","x":[990968],"xaxis":"x","y":[1004902],"yaxis":"y"},{"hovertemplate":"State/UTs=Dadra and Nagar Haveli and Daman and Diu<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Dadra and Nagar Haveli and Daman and Diu","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Dadra and Nagar Haveli and Daman and Diu","orientation":"v","showlegend":true,"type":"scatter","x":[10661],"xaxis":"x","y":[10670],"yaxis":"y"},{"hovertemplate":"State/UTs=Delhi<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"type":"scatter","x":[1412790],"xaxis":"x","y":[1438250],"yaxis":"y"},{"hovertemplate":"State/UTs=Goa<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"type":"scatter","x":[170972],"xaxis":"x","y":[174891],"yaxis":"y"},{"hovertemplate":"State/UTs=Gujarat<br>Discharged=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Gujarat","orientation":"v","showlegend":true,"type":"scatter","x":[815386],"xaxis":"x","y":[825629],"yaxis" ...

# %%
px.scatter(data, x="Death Ratio (%)", y="Total Cases", color=data['State/UTs'], title="Total cases v/s death ratio(%)")
# Out:
# <div>                            <div id="46bb6376-bd46-4995-bd32-9777a2a906bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46bb6376-bd46-4995-bd32-9777a2a906bc")) {                    Plotly.newPlot(                        "46bb6376-bd46-4995-bd32-9777a2a906bc",                        [{"hovertemplate":"State/UTs=Andaman and Nicobar<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andaman and Nicobar","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andaman and Nicobar","orientation":"v","showlegend":true,"type":"scatter","x":[1.7],"xaxis":"x","y":[7584],"yaxis":"y"},{"hovertemplate":"State/UTs=Andhra Pradesh<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[0.69],"xaxis":"x","y":[2030849],"yaxis":"y"},{"hovertemplate":"State/UTs=Arunachal Pradesh<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Arunachal Pradesh","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Arunachal Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[0.5],"xaxis":"x","y":[53807],"yaxis":"y"},{"hovertemplate":"State/UTs=Assam<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"type":"scatter","x":[0.97],"xaxis":"x","y":[595669],"yaxis":"y"},{"hovertemplate":"State/UTs=Bihar<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"type":"scatter","x":[1.33],"xaxis":"x","y":[725833],"yaxis":"y"},{"hovertemplate":"State/UTs=Chandigarh<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chandigarh","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Chandigarh","orientation":"v","showlegend":true,"type":"scatter","x":[1.25],"xaxis":"x","y":[65160],"yaxis":"y"},{"hovertemplate":"State/UTs=Chhattisgarh<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"type":"scatter","x":[1.35],"xaxis":"x","y":[1004902],"yaxis":"y"},{"hovertemplate":"State/UTs=Dadra and Nagar Haveli and Daman and Diu<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Dadra and Nagar Haveli and Daman and Diu","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Dadra and Nagar Haveli and Daman and Diu","orientation":"v","showlegend":true,"type":"scatter","x":[0.04],"xaxis":"x","y":[10670],"yaxis":"y"},{"hovertemplate":"State/UTs=Delhi<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"type":"scatter","x":[1.74],"xaxis":"x","y":[1438250],"yaxis":"y"},{"hovertemplate":"State/UTs=Goa<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"type":"scatter","x":[1.84],"xaxis":"x","y":[174891],"yaxis":"y"},{"hovertemplate":"State/UTs=Gujarat<br>Death Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Gujarat","orientation":"v","showlegend":true,"type":"scatter","x":[1.22 ...

# %%
px.scatter(data, x="Active Ratio (%)", y="Total Cases", color=data['State/UTs'], title="Total cases v/s Active ratio(%)")
# Out:
# <div>                            <div id="34327350-ad10-498f-983f-85e00893c377" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34327350-ad10-498f-983f-85e00893c377")) {                    Plotly.newPlot(                        "34327350-ad10-498f-983f-85e00893c377",                        [{"hovertemplate":"State/UTs=Andaman and Nicobar<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andaman and Nicobar","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andaman and Nicobar","orientation":"v","showlegend":true,"type":"scatter","x":[0.11],"xaxis":"x","y":[7584],"yaxis":"y"},{"hovertemplate":"State/UTs=Andhra Pradesh<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[0.72],"xaxis":"x","y":[2030849],"yaxis":"y"},{"hovertemplate":"State/UTs=Arunachal Pradesh<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Arunachal Pradesh","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Arunachal Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[0.99],"xaxis":"x","y":[53807],"yaxis":"y"},{"hovertemplate":"State/UTs=Assam<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"type":"scatter","x":[0.94],"xaxis":"x","y":[595669],"yaxis":"y"},{"hovertemplate":"State/UTs=Bihar<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"type":"scatter","x":[0.01],"xaxis":"x","y":[725833],"yaxis":"y"},{"hovertemplate":"State/UTs=Chandigarh<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chandigarh","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Chandigarh","orientation":"v","showlegend":true,"type":"scatter","x":[0.05],"xaxis":"x","y":[65160],"yaxis":"y"},{"hovertemplate":"State/UTs=Chhattisgarh<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"type":"scatter","x":[0.04],"xaxis":"x","y":[1004902],"yaxis":"y"},{"hovertemplate":"State/UTs=Dadra and Nagar Haveli and Daman and Diu<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Dadra and Nagar Haveli and Daman and Diu","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Dadra and Nagar Haveli and Daman and Diu","orientation":"v","showlegend":true,"type":"scatter","x":[0.05],"xaxis":"x","y":[10670],"yaxis":"y"},{"hovertemplate":"State/UTs=Delhi<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"type":"scatter","x":[0.03],"xaxis":"x","y":[1438250],"yaxis":"y"},{"hovertemplate":"State/UTs=Goa<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"type":"scatter","x":[0.4],"xaxis":"x","y":[174891],"yaxis":"y"},{"hovertemplate":"State/UTs=Gujarat<br>Active Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Gujarat","orientation":"v","showlegend":true,"type":"scatte ...

# %%
px.scatter(data, x="Discharge Ratio (%)", y="Total Cases", color=data['State/UTs'], title="Total cases v/s Discharge ratio(%)")
# Out:
# <div>                            <div id="a6875403-328a-4c60-8b0d-5dd78497d70b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6875403-328a-4c60-8b0d-5dd78497d70b")) {                    Plotly.newPlot(                        "a6875403-328a-4c60-8b0d-5dd78497d70b",                        [{"hovertemplate":"State/UTs=Andaman and Nicobar<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andaman and Nicobar","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andaman and Nicobar","orientation":"v","showlegend":true,"type":"scatter","x":[98.19],"xaxis":"x","y":[7584],"yaxis":"y"},{"hovertemplate":"State/UTs=Andhra Pradesh<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[98.59],"xaxis":"x","y":[2030849],"yaxis":"y"},{"hovertemplate":"State/UTs=Arunachal Pradesh<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Arunachal Pradesh","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Arunachal Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[98.51],"xaxis":"x","y":[53807],"yaxis":"y"},{"hovertemplate":"State/UTs=Assam<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Assam","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"type":"scatter","x":[98.09],"xaxis":"x","y":[595669],"yaxis":"y"},{"hovertemplate":"State/UTs=Bihar<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"type":"scatter","x":[98.66],"xaxis":"x","y":[725833],"yaxis":"y"},{"hovertemplate":"State/UTs=Chandigarh<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chandigarh","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Chandigarh","orientation":"v","showlegend":true,"type":"scatter","x":[98.7],"xaxis":"x","y":[65160],"yaxis":"y"},{"hovertemplate":"State/UTs=Chhattisgarh<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"type":"scatter","x":[98.61],"xaxis":"x","y":[1004902],"yaxis":"y"},{"hovertemplate":"State/UTs=Dadra and Nagar Haveli and Daman and Diu<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Dadra and Nagar Haveli and Daman and Diu","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Dadra and Nagar Haveli and Daman and Diu","orientation":"v","showlegend":true,"type":"scatter","x":[99.92],"xaxis":"x","y":[10670],"yaxis":"y"},{"hovertemplate":"State/UTs=Delhi<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"type":"scatter","x":[98.23],"xaxis":"x","y":[1438250],"yaxis":"y"},{"hovertemplate":"State/UTs=Goa<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Goa","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"type":"scatter","x":[97.76],"xaxis":"x","y":[174891],"yaxis":"y"},{"hovertemplate":"State/UTs=Gujarat<br>Discharge Ratio (%)=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Gujarat","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Gujarat","orient ...

# %%
px.scatter(data, x="Active", y="Total Cases", color=data['State/UTs'], log_y=True,log_x=True,size="Deaths", size_max=50, title="Total cases v/s Active")
# Out:
# <div>                            <div id="3cc379aa-0a9a-4d27-9c36-e96a7ee47687" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cc379aa-0a9a-4d27-9c36-e96a7ee47687")) {                    Plotly.newPlot(                        "3cc379aa-0a9a-4d27-9c36-e96a7ee47687",                        [{"hovertemplate":"State/UTs=Andaman and Nicobar<br>Active=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Andaman and Nicobar","marker":{"color":"#636efa","size":[129],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Andaman and Nicobar","orientation":"v","showlegend":true,"type":"scatter","x":[8],"xaxis":"x","y":[7584],"yaxis":"y"},{"hovertemplate":"State/UTs=Andhra Pradesh<br>Active=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#EF553B","size":[14010],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[14652],"xaxis":"x","y":[2030849],"yaxis":"y"},{"hovertemplate":"State/UTs=Arunachal Pradesh<br>Active=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Arunachal Pradesh","marker":{"color":"#00cc96","size":[270],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Arunachal Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[533],"xaxis":"x","y":[53807],"yaxis":"y"},{"hovertemplate":"State/UTs=Assam<br>Active=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Assam","marker":{"color":"#ab63fa","size":[5758],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"type":"scatter","x":[5615],"xaxis":"x","y":[595669],"yaxis":"y"},{"hovertemplate":"State/UTs=Bihar<br>Active=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#FFA15A","size":[9658],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"type":"scatter","x":[77],"xaxis":"x","y":[725833],"yaxis":"y"},{"hovertemplate":"State/UTs=Chandigarh<br>Active=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Chandigarh","marker":{"color":"#19d3f3","size":[817],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Chandigarh","orientation":"v","showlegend":true,"type":"scatter","x":[32],"xaxis":"x","y":[65160],"yaxis":"y"},{"hovertemplate":"State/UTs=Chhattisgarh<br>Active=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#FF6692","size":[13558],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"type":"scatter","x":[376],"xaxis":"x","y":[1004902],"yaxis":"y"},{"hovertemplate":"State/UTs=Dadra and Nagar Haveli and Daman and Diu<br>Active=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Dadra and Nagar Haveli and Daman and Diu","marker":{"color":"#B6E880","size":[4],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Dadra and Nagar Haveli and Daman and Diu","orientation":"v","showlegend":true,"type":"scatter","x":[5],"xaxis":"x","y":[10670],"yaxis":"y"},{"hovertemplate":"State/UTs=Delhi<br>Active=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FF97FF","size":[25083],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"type":"scatter","x":[377],"xaxis":"x", ...

# %%
px.scatter(data, x="Discharged", y="Total Cases", color=data['State/UTs'], size="Deaths", size_max=50, title="Total cases v/s Discharged")
# Out:
# <div>                            <div id="775a9ab4-c7bd-4bbc-9365-cb09ee8b1779" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("775a9ab4-c7bd-4bbc-9365-cb09ee8b1779")) {                    Plotly.newPlot(                        "775a9ab4-c7bd-4bbc-9365-cb09ee8b1779",                        [{"hovertemplate":"State/UTs=Andaman and Nicobar<br>Discharged=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Andaman and Nicobar","marker":{"color":"#636efa","size":[129],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Andaman and Nicobar","orientation":"v","showlegend":true,"type":"scatter","x":[7447],"xaxis":"x","y":[7584],"yaxis":"y"},{"hovertemplate":"State/UTs=Andhra Pradesh<br>Discharged=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#EF553B","size":[14010],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[2002187],"xaxis":"x","y":[2030849],"yaxis":"y"},{"hovertemplate":"State/UTs=Arunachal Pradesh<br>Discharged=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Arunachal Pradesh","marker":{"color":"#00cc96","size":[270],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Arunachal Pradesh","orientation":"v","showlegend":true,"type":"scatter","x":[53004],"xaxis":"x","y":[53807],"yaxis":"y"},{"hovertemplate":"State/UTs=Assam<br>Discharged=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Assam","marker":{"color":"#ab63fa","size":[5758],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"type":"scatter","x":[584296],"xaxis":"x","y":[595669],"yaxis":"y"},{"hovertemplate":"State/UTs=Bihar<br>Discharged=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Bihar","marker":{"color":"#FFA15A","size":[9658],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"type":"scatter","x":[716098],"xaxis":"x","y":[725833],"yaxis":"y"},{"hovertemplate":"State/UTs=Chandigarh<br>Discharged=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Chandigarh","marker":{"color":"#19d3f3","size":[817],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Chandigarh","orientation":"v","showlegend":true,"type":"scatter","x":[64311],"xaxis":"x","y":[65160],"yaxis":"y"},{"hovertemplate":"State/UTs=Chhattisgarh<br>Discharged=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#FF6692","size":[13558],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"type":"scatter","x":[990968],"xaxis":"x","y":[1004902],"yaxis":"y"},{"hovertemplate":"State/UTs=Dadra and Nagar Haveli and Daman and Diu<br>Discharged=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Dadra and Nagar Haveli and Daman and Diu","marker":{"color":"#B6E880","size":[4],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Dadra and Nagar Haveli and Daman and Diu","orientation":"v","showlegend":true,"type":"scatter","x":[10661],"xaxis":"x","y":[10670],"yaxis":"y"},{"hovertemplate":"State/UTs=Delhi<br>Discharged=%{x}<br>Total Cases=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FF97FF","size":[25083],"sizemode":"area","sizeref":55.2676,"symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v ...

# %%
fig = px.choropleth(data,
                    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM', locations='State/UTs',color='Total Cases',color_continuous_scale="Blues", title="Total cases density plot")
fig.update_geos(fitbounds="locations", visible=False)
fig.show()
# Out:
# <div>                            <div id="21f603a8-5c37-4f27-9db8-d93d3ee14899" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21f603a8-5c37-4f27-9db8-d93d3ee14899")) {                    Plotly.newPlot(                        "21f603a8-5c37-4f27-9db8-d93d3ee14899",                        [{"coloraxis":"coloraxis","featureidkey":"properties.ST_NM","geo":"geo","geojson":"https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson","hovertemplate":"State/UTs=%{location}<br>Total Cases=%{z}<extra></extra>","locations":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"","type":"choropleth","z":[7584,2030849,53807,595669,725833,65160,1004902,10670,1438250,174891,825629,770659,215893,326990,348079,2962408,4390489,20608,10353,792353,6500617,117230,78359,72883,30657,1016833,124836,601072,954198,30650,2635419,661866,83672,1709555,343242,1557414]}],                        {"coloraxis":{"colorbar":{"title":{"text":"Total Cases"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]]},"geo":{"center":{},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"fitbounds":"locations","visible":false},"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern ...

# %%
fig = px.choropleth(data,
                    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM', locations='State/UTs',color='Active',color_continuous_scale="pinkyl", title="Active cases density plot")
fig.update_geos(fitbounds="locations", visible=False)
fig.show()
# Out:
# <div>                            <div id="fda8b7f0-a1c9-447b-97a4-65155618bfe8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fda8b7f0-a1c9-447b-97a4-65155618bfe8")) {                    Plotly.newPlot(                        "fda8b7f0-a1c9-447b-97a4-65155618bfe8",                        [{"coloraxis":"coloraxis","featureidkey":"properties.ST_NM","geo":"geo","geojson":"https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson","hovertemplate":"State/UTs=%{location}<br>Active=%{z}<extra></extra>","locations":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"","type":"choropleth","z":[8,14652,533,5615,77,32,376,5,377,702,161,351,1521,1247,117,16269,209335,30,5,131,53427,2617,1859,13369,580,5919,860,309,90,809,16522,5253,485,175,293,8096]}],                        {"coloraxis":{"colorbar":{"title":{"text":"Active"}},"colorscale":[[0.0,"rgb(254, 246, 181)"],[0.16666666666666666,"rgb(255, 221, 154)"],[0.3333333333333333,"rgb(255, 194, 133)"],[0.5,"rgb(255, 166, 121)"],[0.6666666666666666,"rgb(250, 138, 118)"],[0.8333333333333334,"rgb(241, 109, 122)"],[1.0,"rgb(225, 83, 131)"]]},"geo":{"center":{},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"fitbounds":"locations","visible":false},"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2 ...

# %%
fig = px.choropleth(data,
                    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM', locations='State/UTs',color='Discharged',color_continuous_scale="Greens", title="Discharged cases density plot")
fig.update_geos(fitbounds="locations", visible=False)
fig.show()
# Out:
# <div>                            <div id="ffbd650a-60cf-4d16-90b8-c6a1199a55ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffbd650a-60cf-4d16-90b8-c6a1199a55ac")) {                    Plotly.newPlot(                        "ffbd650a-60cf-4d16-90b8-c6a1199a55ac",                        [{"coloraxis":"coloraxis","featureidkey":"properties.ST_NM","geo":"geo","geojson":"https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson","hovertemplate":"State/UTs=%{location}<br>Discharged=%{z}<extra></extra>","locations":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"","type":"choropleth","z":[7447,2002187,53004,584296,716098,64311,990968,10661,1412790,170972,815386,760501,210733,321329,342829,2908622,4158504,20371,10297,781705,6309021,112801,75141,59273,29432,1002810,122153,584306,945154,29464,2583707,652716,82382,1686497,335560,1530731]}],                        {"coloraxis":{"colorbar":{"title":{"text":"Discharged"}},"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"geo":{"center":{},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"fitbounds":"locations","visible":false},"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fi ...

# %%
fig = px.choropleth(data,
                    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM', locations='State/UTs',color='Deaths',color_continuous_scale="Reds", title="Death cases density plot")
fig.update_geos(fitbounds="locations", visible=False)
fig.show()
# Out:
# <div>                            <div id="229c267c-6dd7-4e11-a695-f4c8e8962d60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("229c267c-6dd7-4e11-a695-f4c8e8962d60")) {                    Plotly.newPlot(                        "229c267c-6dd7-4e11-a695-f4c8e8962d60",                        [{"coloraxis":"coloraxis","featureidkey":"properties.ST_NM","geo":"geo","geojson":"https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson","hovertemplate":"State/UTs=%{location}<br>Deaths=%{z}<extra></extra>","locations":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"","type":"choropleth","z":[129,14010,270,5758,9658,817,13558,4,25083,3217,10082,9807,3639,4414,5133,37517,22650,207,51,10517,138169,1812,1359,241,645,8104,1823,16457,8954,377,35190,3897,805,22883,7389,18587]}],                        {"coloraxis":{"colorbar":{"title":{"text":"Deaths"}},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]]},"geo":{"center":{},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"fitbounds":"locations","visible":false},"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram ...

# %%
px.pie(data,values='Total Cases', names=data['State/UTs'], title='Covid cases (%) in states of India')
# Out:
# <div>                            <div id="1fda4016-978f-4569-8bff-90687015b277" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fda4016-978f-4569-8bff-90687015b277")) {                    Plotly.newPlot(                        "1fda4016-978f-4569-8bff-90687015b277",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"State/UTs=%{label}<br>Total Cases=%{value}<extra></extra>","labels":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[7584,2030849,53807,595669,725833,65160,1004902,10670,1438250,174891,825629,770659,215893,326990,348079,2962408,4390489,20608,10353,792353,6500617,117230,78359,72883,30657,1016833,124836,601072,954198,30650,2635419,661866,83672,1709555,343242,1557414]}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111111 ...

# %%
px.pie(data,values='Active', names=data['State/UTs'], width=1400, height=800, title='Active cases (%) in states of India')
# Out:
# <div>                            <div id="6093b95a-6fad-4a0c-a3a9-068a66216006" class="plotly-graph-div" style="height:800px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6093b95a-6fad-4a0c-a3a9-068a66216006")) {                    Plotly.newPlot(                        "6093b95a-6fad-4a0c-a3a9-068a66216006",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"State/UTs=%{label}<br>Active=%{value}<extra></extra>","labels":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[8,14652,533,5615,77,32,376,5,377,702,161,351,1521,1247,117,16269,209335,30,5,131,53427,2617,1859,13369,580,5919,860,309,90,809,16522,5253,485,175,293,8096]}],                        {"height":800,"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4 ...

# %%
px.pie(data,values='Discharged', names=data['State/UTs'], title='Discharged cases (%) in states of India')
# Out:
# <div>                            <div id="41d5f6ed-fdc9-4504-bd22-3d1d8e1f092a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41d5f6ed-fdc9-4504-bd22-3d1d8e1f092a")) {                    Plotly.newPlot(                        "41d5f6ed-fdc9-4504-bd22-3d1d8e1f092a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"State/UTs=%{label}<br>Discharged=%{value}<extra></extra>","labels":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[7447,2002187,53004,584296,716098,64311,990968,10661,1412790,170972,815386,760501,210733,321329,342829,2908622,4158504,20371,10297,781705,6309021,112801,75141,59273,29432,1002810,122153,584306,945154,29464,2583707,652716,82382,1686497,335560,1530731]}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111 ...

# %%
px.pie(data,values='Deaths', names=data['State/UTs'], width=1400, height=600,title='Death cases (%) in states of India')
# Out:
# <div>                            <div id="760e530b-03aa-4933-84f8-7cb6981961c4" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("760e530b-03aa-4933-84f8-7cb6981961c4")) {                    Plotly.newPlot(                        "760e530b-03aa-4933-84f8-7cb6981961c4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"State/UTs=%{label}<br>Deaths=%{value}<extra></extra>","labels":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[129,14010,270,5758,9658,817,13558,4,25083,3217,10082,9807,3639,4414,5133,37517,22650,207,51,10517,138169,1812,1359,241,645,8104,1823,16457,8954,377,35190,3897,805,22883,7389,18587]}],                        {"height":600,"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333 ...
